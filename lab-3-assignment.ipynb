# %%
import pandas as pd
import numpy as np

# %%
# 1 Pandas Series — Marks
marks = pd.Series([78, 85, 92, 67, 88])

print("Complete Series:")
print(marks)

print("\nValues:")
print(marks.values)

print("\nIndex:")
print(marks.index)

print("\nData type:")
print(marks.dtype)

print("\nMean:")
print(marks.mean())

print("\nMaximum:")
print(marks.max())

print("\nMinimum:")
print(marks.min())
# Out:
# Complete Series:
# 0    78
# 1    85
# 2    92
# 3    67
# 4    88
# dtype: int64
#
# Values:
# [78 85 92 67 88]
#
# Index:
# RangeIndex(start=0, stop=5, step=1)
#
# Data type:
# int64
#
# Mean:
# 82.0
#
# Maximum:
# 92
#
# Minimum:
# 67

# %%
# 2. Series with Student Names

marks = pd.Series(
    [85, 78, 92, 74, 88],
    index=["Asha", "Ravi", "Meena", "Kiran", "Arun"]
)

print(marks)

print("\nMarks of Meena:")
print(marks["Meena"])
# Out:
# Asha     85
# Ravi     78
# Meena    92
# Kiran    74
# Arun     88
# dtype: int64
#
# Marks of Meena:
# 92

# %%
# 3. Create DataFrame
data = {
    "Name": ["Asha", "Ravi", "Meena", "Kiran", "Arun"],
    "Age": [22, 23, 21, 24, 22],
    "Department": ["CSE", "ECE", "CSE", "ME", "ECE"],
    "Marks": [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)

print("Complete DataFrame:")
print(df)

print("\nFirst 3 rows:")
print(df.head(3))

print("\nLast 2 rows:")
print(df.tail(2))
# Out:
# Complete DataFrame:
#     Name  Age Department  Marks
# 0   Asha   22        CSE     85
# 1   Ravi   23        ECE     78
# 2  Meena   21        CSE     92
# 3  Kiran   24         ME     74
# 4   Arun   22        ECE     88
#
# First 3 rows:
#     Name  Age Department  Marks
# 0   Asha   22        CSE     85
# 1   Ravi   23        ECE     78
# 2  Meena   21        CSE     92
#
# Last 2 rows:
#     Name  Age Department  Marks
# 3  Kiran   24         ME     74
# 4   Arun   22        ECE     88

# %%
print("\nShape:---")
print(df.shape)

print("\nColumn names:")
print(df.columns)

print("\nData types:---\n")
print(df.dtypes)
# Out:
# Shape:---
# (5, 4)
#
# Column names:
# Index(['Name', 'Age', 'Department', 'Marks'], dtype='str')
#
# Data types:---
#
# Name            str
# Age           int64
# Department      str
# Marks         int64
# dtype: object

# %%
#4. info(), describe(), Rows and Columns
print("Info:-\n")
df.info()
#print("\n")

print("\nDescribe:-\n")
print(df.describe())

print("\nNumber of rows:-\n")
print(df.shape[0])

print("\nNumber of columns:-")
print(df.shape[1])
# Out:
# Info:-
#
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      str
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      str
#  3   Marks       5 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 292.0 bytes
#
# Describe:-
#
#              Age      Marks
# count   5.000000   5.000000
# mean   22.400000  83.400000
# std     1.140175   7.334848
# min    21.000000  74.000000
# 25%    22.000000  78.000000
# 50%    22.000000  85.000000
# 75%    23.000000  88.000000
# max    24.000000  92.000000
#
# Number of rows:-
#
# 5
#
# Number of columns:-
# 4

# %%
#5. 
# Selecting Name Column

# %%
df[["Name"]]
# Out:
#     Name
# 0   Asha
# 1   Ravi
# 2  Meena
# 3  Kiran
# 4   Arun

# %%
df[["Marks"]]    # marks
# Out:
#    Marks
# 0     85
# 1     78
# 2     92
# 3     74
# 4     88

# %%
df[["Name", "Marks"]]   # name & marks
# Out:
#     Name  Marks
# 0   Asha     85
# 1   Ravi     78
# 2  Meena     92
# 3  Kiran     74
# 4   Arun     88

# %%
#6. Using iloc and loc

# %%
print(df.iloc[0])  # First row using iloc
# Out:
# Name          Asha
# Age             22
# Department     CSE
# Marks           85
# Name: 0, dtype: object

# %%
print(df.iloc[2])    #Third row using iloc
# Out:
# Name          Meena
# Age              21
# Department      CSE
# Marks            92
# Name: 2, dtype: object

# %%
print(df.iloc[1:4])   #Rows 1 to 3
# Out:
#     Name  Age Department  Marks
# 1   Ravi   23        ECE     78
# 2  Meena   21        CSE     92
# 3  Kiran   24         ME     74

# %%
#Name and Marks using loc
print(df.loc[:, ["Name", "Marks"]])
# Out:
#     Name  Marks
# 0   Asha     85
# 1   Ravi     78
# 2  Meena     92
# 3  Kiran     74
# 4   Arun     88

# %%
#7. Filtering Data

print(df[df["Marks"] > 80])
# Out:
#     Name  Age Department  Marks
# 0   Asha   22        CSE     85
# 2  Meena   21        CSE     92
# 4   Arun   22        ECE     88

# %%
print(df[(df["Marks"] >= 75) & (df["Marks"] <= 90)])
# Out:
#    Name  Age Department  Marks
# 0  Asha   22        CSE     85
# 1  Ravi   23        ECE     78
# 4  Arun   22        ECE     88

# %%
print(df[df["Marks"].between(75, 90)])
# Out:
#    Name  Age Department  Marks
# 0  Asha   22        CSE     85
# 1  Ravi   23        ECE     78
# 4  Arun   22        ECE     88

# %%
print(df[df["Department"] == "CSE"])
# Out:
#     Name  Age Department  Marks
# 0   Asha   22        CSE     85
# 2  Meena   21        CSE     92

# %%
print(df[(df["Department"] == "CSE") & (df["Marks"] > 80)])
# Out:
#     Name  Age Department  Marks
# 0   Asha   22        CSE     85
# 2  Meena   21        CSE     92

# %%
# 8. Students belonging to CSE or ECE

print(df[df["Department"].isin(["CSE", "ECE"])])
# Out:
#     Name  Age Department  Marks
# 0   Asha   22        CSE     85
# 1   Ravi   23        ECE     78
# 2  Meena   21        CSE     92
# 4   Arun   22        ECE     88

# %%
#9. Add Result Column

df["Result"] = np.where(df["Marks"] >= 75, "Pass", "Fail")

print(df)
# Out:
#     Name  Age Department  Marks Result
# 0   Asha   22        CSE     85   Pass
# 1   Ravi   23        ECE     78   Pass
# 2  Meena   21        CSE     92   Pass
# 3  Kiran   24         ME     74   Fail
# 4   Arun   22        ECE     88   Pass

# %%
#10. Add Grade Column
def grade(marks):
    if marks >= 90:
        return "A"
    elif marks >= 80:
        return "B"
    elif marks >= 70:
        return "C"
    else:
        return "D"

df["Grade"] = df["Marks"].apply(grade)

print(df)
# Out:
#     Name  Age Department  Marks Result Grade
# 0   Asha   22        CSE     85   Pass     B
# 1   Ravi   23        ECE     78   Pass     C
# 2  Meena   21        CSE     92   Pass     A
# 3  Kiran   24         ME     74   Fail     C
# 4   Arun   22        ECE     88   Pass     B

# %%
#11. Sorting Students

# %%
#Marks ascending
print(df.sort_values("Marks"))

print("\n")
#Marks descending
print(df.sort_values("Marks", ascending=False))
# Out:
#     Name  Age Department  Marks Result Grade
# 3  Kiran   24         ME     74   Fail     C
# 1   Ravi   23        ECE     78   Pass     C
# 0   Asha   22        CSE     85   Pass     B
# 4   Arun   22        ECE     88   Pass     B
# 2  Meena   21        CSE     92   Pass     A
#
#
#     Name  Age Department  Marks Result Grade
# 2  Meena   21        CSE     92   Pass     A
# 4   Arun   22        ECE     88   Pass     B
# 0   Asha   22        CSE     85   Pass     B
# 1   Ravi   23        ECE     78   Pass     C
# 3  Kiran   24         ME     74   Fail     C

# %%
#Department and then Marks
print(df.sort_values(["Department", "Marks"]))
# Out:
#     Name  Age Department  Marks Result Grade
# 0   Asha   22        CSE     85   Pass     B
# 2  Meena   21        CSE     92   Pass     A
# 1   Ravi   23        ECE     78   Pass     C
# 4   Arun   22        ECE     88   Pass     B
# 3  Kiran   24         ME     74   Fail     C

# %%
#12. Missing Values
data = {
    "Name": ["Asha", "Ravi", "Meena", "Kiran", "Arun"],
    "Age": [22, 23, np.nan, 24, 22],
    "Marks": [85, np.nan, 92, 74, 88]
}

students = pd.DataFrame(data)

print("DataFrame:")
print(students)

print("\nMissing values:")
print(students.isnull())

print("\nNumber of missing values in each column:")
print(students.isnull().sum())

print("\nRows containing missing values:")
print(students[students.isnull().any(axis=1)])
# Out:
# DataFrame:
#     Name   Age  Marks
# 0   Asha  22.0   85.0
# 1   Ravi  23.0    NaN
# 2  Meena   NaN   92.0
# 3  Kiran  24.0   74.0
# 4   Arun  22.0   88.0
#
# Missing values:
#     Name    Age  Marks
# 0  False  False  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4  False  False  False
#
# Number of missing values in each column:
# Name     0
# Age      1
# Marks    1
# dtype: int64
#
# Rows containing missing values:
#     Name   Age  Marks
# 1   Ravi  23.0    NaN
# 2  Meena   NaN   92.0

# %%
#13. Replace Missing Values with Average
students["Age"] = students["Age"].fillna(students["Age"].mean())

students["Marks"] = students["Marks"].fillna(students["Marks"].mean())

print(students)
# Out:
#     Name    Age  Marks
# 0   Asha  22.00  85.00
# 1   Ravi  23.00  84.75
# 2  Meena  22.75  92.00
# 3  Kiran  24.00  74.00
# 4   Arun  22.00  88.00

# %%
#14. Remove Rows Containing Missing Values

students = students.dropna() # updates the actual dataframe

print(students ,"\n")

#don't want to permanently change the DataFrame then
print(students.dropna())
# Out:
#     Name    Age  Marks
# 0   Asha  22.00  85.00
# 1   Ravi  23.00  84.75
# 2  Meena  22.75  92.00
# 3  Kiran  24.00  74.00
# 4   Arun  22.00  88.00
#
#     Name    Age  Marks
# 0   Asha  22.00  85.00
# 1   Ravi  23.00  84.75
# 2  Meena  22.75  92.00
# 3  Kiran  24.00  74.00
# 4   Arun  22.00  88.00

# %%
#15. Find and Remove Duplicates

data = {
    "Name": ["Asha", "Ravi", "Meena", "Asha", "Arun"],
    "Marks": [85, 78, 92, 85, 88]
}

df2 = pd.DataFrame(data)

print("DataFrame:")
print(df2)

print("\nDuplicate rows:")
print(df2[df2.duplicated()])

print("\nAfter removing duplicates:")
print(df2.drop_duplicates())
# Out:
# DataFrame:
#     Name  Marks
# 0   Asha     85
# 1   Ravi     78
# 2  Meena     92
# 3   Asha     85
# 4   Arun     88
#
# Duplicate rows:
#    Name  Marks
# 3  Asha     85
#
# After removing duplicates:
#     Name  Marks
# 0   Asha     85
# 1   Ravi     78
# 2  Meena     92
# 4   Arun     88

# %%
#16. Statistical Calculations
marks = pd.DataFrame(
    {
    "Student": ["A", "B", "C", "D", "E"],
    "Marks": [78, 85, 92, 67, 88]
    }
)

print("Mean:", marks["Marks"].mean())
print("Median:", marks["Marks"].median())
print("Maximum:", marks["Marks"].max())
print("Minimum:", marks["Marks"].min())
print("Standard deviation:", marks["Marks"].std())
print("Sum:", marks["Marks"].sum())
# Out:
# Mean: 82.0
# Median: 85.0
# Maximum: 92
# Minimum: 67
# Standard deviation: 9.82344135219425
# Sum: 410

# %%
#17. GroupBy — Department Analysis
data = {
    "Name": [
        "Asha", "Ravi", "Meena",
        "Kiran", "Arun", "Divya"
    ],
    "Department": [
        "CSE", "ECE", "CSE",
        "ME", "ECE", "CSE"
    ],
    "Marks": [
        85, 78, 92,
        74, 88, 80
    ]
}

df = pd.DataFrame(data)

# %%
#Average marks by department

print(df.groupby("Department")["Marks"].mean())
# Out:
# Department
# CSE    85.666667
# ECE    83.000000
# ME     74.000000
# Name: Marks, dtype: float64

# %%
#Maximum marks by department

print(df.groupby("Department")["Marks"].max())
# Out:
# Department
# CSE    92
# ECE    88
# ME     74
# Name: Marks, dtype: int64

# %%
#Number of students

print(df.groupby("Department")["Name"].count())
# Out:
# Department
# CSE    3
# ECE    2
# ME     1
# Name: Name, dtype: int64

# %%
df.groupby("Department")["Marks"].agg(["mean_or_avg", "min", "max", "count"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df.groupby("Department")["Marks"].agg(["mean(avg)", "min", "max", "count"])
#
# File d:\Practice_SMJ\.venv-1\Lib\site-packages\pandas\core\groupby\generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# File d:\Practice_SMJ\.venv-1\Lib\site-packages\pandas\core\groupby\generic.py:522, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     520     for idx, (name, func) in enumerate(arg):
#     521         key = base.OutputKey(label=name, position=idx)
# --> 522         results[key] = self.aggregate(func, *args, **kwargs)
#     524 if any(isinstance(x, DataFrame) for x in results.values()):
#     525     from pandas import concat
#
# File d:\Practice_SMJ\.venv-1\Lib\site-packages\pandas\core\groupby\generic.py:456, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     454     if engine_kwargs is not None:
#     455         kwargs["engine_kwargs"] = engine_kwargs
# --> 456     return getattr(self, func)(*args, **kwargs)
#     458 elif isinstance(func, abc.Iterable):
#     459     # Catch instances of lists / tuples
#     460     # but not the class list / tuple itself.
#     461     func = maybe_mangle_lambdas(func)
#
# File d:\Practice_SMJ\.venv-1\Lib\site-packages\pandas\core\groupby\groupby.py:1115, in GroupBy.__getattr__(self, attr)
#    1112 if attr in self.obj:
#    1113     return self[attr]
# -> 1115 raise AttributeError(
#    1116     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1117 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'mean(avg)'
